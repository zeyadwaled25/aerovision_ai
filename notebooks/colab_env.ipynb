# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
cd /content/drive/MyDrive/aerovision_ai
# Out:
# /content/drive/MyDrive/aerovision_ai

# %%
# !pip install yacs

# %%
# !python main.py --dataset_dir data --split public_lb
